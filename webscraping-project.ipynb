# %%
import numpy as np
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
url_oscar = 'https://editorial.rottentomatoes.com/guide/oscars-best-and-worst-best-pictures/'

# %%
response = requests.get(url_oscar)

# %%
html = response.content

# %%
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="We welcome Parasite to our list of every Best Picture Oscar winner ranked by Tomatometer! How many have you seen?" property="og.description"/>
# <meta content="We welcome Parasite to our list of every Best Picture Oscar winner ranked by Tomatometer! How many have you seen?" name="description"/>
# <meta content="All 93 Best Picture Winners, Ranked by Tomatometer" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2020/02/19114413/600OneFlew.jpg" property="og:image"/>
# <meta content="https://editorial.rottentomatoes.com/guide/oscars-best-and-worst-best-pictures/" property="og:url"/>
# <meta content="140214" name="editorialID"/>
# ...

# %%
soup.find_all('h2')[0].text
# Out:
# 'The Broadway Melody (1929)  33%'

# %%
soup.find_all('span')
# Out:
# [<span class="glyphicon glyphicon-remove"></span>,
#  <span class="glyphicon glyphicon-cog"></span>,
#  <span class="name">Jester McGree</span>,
#  <span class="glyphicon glyphicon-remove"></span>,
#  <span class="fontelloIcon icon-down-dir"></span>,
#  <span class="fontelloIcon icon-down-dir"></span>,
#  <span class="fontelloIcon icon-down-dir"></span>,
#  <span class="subtle start-year">(1929)</span>,
#  <span class="icon tiny rotten" title="Rotten"></span>,
#  <span class="tMeterScore">33%</span>,
#  <span class="descriptor">Adjusted Score: </span>,
#  <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span>,
#  <span class="descriptor">Critics Consensus:</span>,
#  <span class="descriptor">Synopsis:</span>,
# ...

# %%
soup.find_all('span', attrs={'class':'subtle start-year'})[0].text
# Out:
# '(1929)'

# %%
soup.find_all('span', attrs={'class':'tMeterScore'})[0].text
# Out:
# '33%'

# %%
soup.find_all('div', attrs={'class':'info director'})[0].text
# Out:
# '\nDirected By: Harry Beaumont'
